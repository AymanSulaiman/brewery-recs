# %%
import os
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/openbrewerydb/openbrewerydb/master/breweries.csv')
df = df.drop(['address_2','address_3','tags','county_province'], axis=1)
df = df[df['longitude'].notna()]
df
# Out:
#                                  obdb_id                             name  \
# 0             10-56-brewing-company-knox            10-56 Brewing Company
# 3     10-barrel-brewing-co-bend-pub-bend  10 Barrel Brewing Co - Bend Pub
# 4       10-barrel-brewing-co-boise-boise     10 Barrel Brewing Co - Boise
# 5     10-barrel-brewing-co-denver-denver    10 Barrel Brewing Co - Denver
# 6          10-barrel-brewing-co-portland             10 Barrel Brewing Co
# ...                                  ...                              ...
# 7855       zorn-brew-works-michigan-city                  Zorn Brew Works
# 7857  zuni-street-brewing-company-denver      Zuni Street Brewing Company
# 7858           zwanzigz-brewing-columbus                 ZwanzigZ Brewing
# 7860             zydeco-brew-werks-tampa                Zydeco Brew Werks
# 7861         zymurgy-brew-works-torrance               Zymurgy Brew Works
#
#      brewery_type                street           city       state  \
# ...
